# %%
import pandas as pd
import numpy as np

# %%
# read in all our data
events_data = pd.read_csv("events.csv")

# %%
# set seed for reproducibility
np.random.seed(0)

# %%
events_data.head()
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
# 2  UFot0hit/  UFot0hit3           3     4
# 3  UFot0hit/  UFot0hit4           4     7
# 4  UFot0hit/  UFot0hit5           5     7
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          NaN
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2          NaN
# 3           Foul by Sven Bender (Borussia Dortmund).           3          NaN
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8          NaN
#
#    side         event_team           opponent  ... player_in player_out  \
# 0     2         Hamburg SV  Borussia Dortmund  ...       NaN        NaN
# 1     1  Borussia Dortmund         Hamburg SV  ...       NaN        NaN
# 2     1  Borussia Dortmund         Hamburg SV  ...       NaN        NaN
# 3     1  Borussia Dortmund         Hamburg SV  ...       NaN        NaN
# 4     2         Hamburg SV  Borussia Dortmund  ...       NaN        NaN
#
#   shot_place shot_outcome  is_goal  location  bodypart  assist_method  \
# 0        6.0          2.0        0       9.0       2.0              1
# 1        NaN          NaN        0       NaN       NaN              0
# 2        NaN          NaN        0       NaN       NaN              0
# 3        NaN          NaN        0       NaN       NaN              0
# 4        NaN          NaN        0       2.0       NaN              0
#
#    situation  fast_break
# 0        1.0           0
# 1        NaN           0
# 2        NaN           0
# 3        NaN           0
# 4        NaN           0
#
# [5 rows x 22 columns]

# %%
# get the number of missing data points per column
missing_values_count = events_data.isnull().sum()

# %%
# look at the # of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# id_odsp             0
# id_event            0
# sort_order          0
# time                0
# text                0
# event_type          0
# event_type2    726716
# side                0
# event_team          0
# opponent            0
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(events_data.shape)
total_missing = missing_values_count.sum()

# %%
# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 31.58929790933311

# %%
# look at the # of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# id_odsp             0
# id_event            0
# sort_order          0
# time                0
# text                0
# event_type          0
# event_type2    726716
# side                0
# event_team          0
# opponent            0
# dtype: int64

# %%
# remove all the rows that contain a missing value
events_data.dropna()
# Out:
# Empty DataFrame
# Columns: [id_odsp, id_event, sort_order, time, text, event_type, event_type2, side, event_team, opponent, player, player2, player_in, player_out, shot_place, shot_outcome, is_goal, location, bodypart, assist_method, situation, fast_break]
# Index: []
#
# [0 rows x 22 columns]

# %%
# remove all columns with at least one missing value
columns_with_na_dropped = events_data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
# 2  UFot0hit/  UFot0hit3           3     4
# 3  UFot0hit/  UFot0hit4           4     7
# 4  UFot0hit/  UFot0hit5           5     7
#
#                                                 text  event_type  side  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1     2
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2     1
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2     1
# 3           Foul by Sven Bender (Borussia Dortmund).           3     1
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8     2
#
#           event_team           opponent  is_goal  assist_method  fast_break
# 0         Hamburg SV  Borussia Dortmund        0              1           0
# 1  Borussia Dortmund         Hamburg SV        0              0           0
# 2  Borussia Dortmund         Hamburg SV        0              0           0
# 3  Borussia Dortmund         Hamburg SV        0              0           0
# 4         Hamburg SV  Borussia Dortmund        0              0           0

# %%
# just how much data did we lose?
print("Columns in original dataset: %d \n" % events_data.shape[1])
print("Columns with na's dropped: %d" % columns_with_na_dropped.shape[1])
# Out:
# Columns in original dataset: 22
#
# Columns with na's dropped: 12

# %%
# get a small subset of the events dataset
subset_events_data = events_data.loc[:, 'id_odsp':'event_team'].head()
subset_events_data
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
# 2  UFot0hit/  UFot0hit3           3     4
# 3  UFot0hit/  UFot0hit4           4     7
# 4  UFot0hit/  UFot0hit5           5     7
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          NaN
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2          NaN
# 3           Foul by Sven Bender (Borussia Dortmund).           3          NaN
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8          NaN
#
#    side         event_team
# 0     2         Hamburg SV
# 1     1  Borussia Dortmund
# 2     1  Borussia Dortmund
# 3     1  Borussia Dortmund
# 4     2         Hamburg SV

# %%
# replace all NA's with 0
subset_events_data.fillna(0)
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
# 2  UFot0hit/  UFot0hit3           3     4
# 3  UFot0hit/  UFot0hit4           4     7
# 4  UFot0hit/  UFot0hit5           5     7
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          0.0
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2          0.0
# 3           Foul by Sven Bender (Borussia Dortmund).           3          0.0
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8          0.0
#
#    side         event_team
# 0     2         Hamburg SV
# 1     1  Borussia Dortmund
# 2     1  Borussia Dortmund
# 3     1  Borussia Dortmund
# 4     2         Hamburg SV

# %%
# replace all NA's the value that comes directly after it in the same column, 
# then replace all the remaining na's with 0
subset_events_data.fillna(method='bfill', axis=0).fillna(0)
# Out:
#      id_odsp   id_event  sort_order  time  \
# 0  UFot0hit/  UFot0hit1           1     2
# 1  UFot0hit/  UFot0hit2           2     4
# 2  UFot0hit/  UFot0hit3           3     4
# 3  UFot0hit/  UFot0hit4           4     7
# 4  UFot0hit/  UFot0hit5           5     7
#
#                                                 text  event_type  event_type2  \
# 0  Attempt missed. Mladen Petric (Hamburg) left f...           1         12.0
# 1  Corner,  Borussia Dortmund. Conceded by Dennis...           2          0.0
# 2  Corner,  Borussia Dortmund. Conceded by Heiko ...           2          0.0
# 3           Foul by Sven Bender (Borussia Dortmund).           3          0.0
# 4  Gokhan Tore (Hamburg) wins a free kick in the ...           8          0.0
#
#    side         event_team
# 0     2         Hamburg SV
# 1     1  Borussia Dortmund
# 2     1  Borussia Dortmund
# 3     1  Borussia Dortmund
# 4     2         Hamburg SV
